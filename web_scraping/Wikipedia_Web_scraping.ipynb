# %%
# %pip install requests beautifulsoup4

# %%
dbutils.library.restartPython()

# %%
# Find the "Episodes" section header
episodes_header = soup.find('h2', id='Episodes')

# Find the table immediately following the "Episodes" header
episodes_table = episodes_header.find_next('table', class_='wikitable')

# Find all episode rows under this table
episodes = episodes_table.find_all('tr', class_='vevent module-episode-list-row')

# %%
from pyspark.sql import Row
import requests
from bs4 import BeautifulSoup

url = "https://en.wikipedia.org/wiki/List_of_Breaking_Bad_episodes"

# This header tells the server you are a Chrome browser on Windows
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    # Your scraping logic here...
    print("Success! Data retrieved.")
else:
    print(f"Error! Status code: {response.status_code}")
    if response.status_code == 403:
        print("Still forbidden. The site might be using an advanced bot-blocker.")

soup = BeautifulSoup(response.text, 'html.parser')

# Find the "Episodes" section header
episodes_header = soup.find('h2', id='Episodes')

# Find all tables with class 'wikitable' after the "Episodes" header
episodes_tables = episodes_header.find_all_next('table', class_='wikitable plainrowheaders wikiepisodetable')

# # Find all episode rows under this table
# episodes = episodes_tables.find('tr', class_='vevent module-episode-list-row')
# rows = []
# for ep in episodes:
#     # 'No. overall' is in a <th> tag
#     no_overall = ep.find('th').get_text(strip=True)
    
#     # Other data points are in <td> tags
#     details = ep.find_all('td')
    
#     no_in_season = details[0].get_text(strip=True)
#     title = details[1].get_text(strip=True).replace('"', '')
#     directed_by = details[2].get_text(strip=True)
#     written_by = details[3].get_text(strip=True)
#     rows.append(Row(Episode = no_overall, Title = title, Directed_by = directed_by, Written_by = written_by))
#     print(f"Ep {no_overall}: {title} | Directed by: {directed_by}")

# df = spark.createDataFrame(rows)

# %%
episodes_header

# %%
episodes_header

# %%
episodes_tables

# %%
episodes_table

# %%
display(df)
