# %%
import requests

# api_url = "https://api.openweathermap.org/data/3.0/onecall?lat=33.44&lon=-94.04&exclude=hourly,daily&appid=a1918ac0abd75475262faf6f0ed3a5ca"
# response = requests.get(api_url)

url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": 28.58,
	"longitude": 77.33,
	"hourly": "temperature_2m",
}
responses = requests.get(url, params=params)
weather_data = responses.json()
df = spark.createDataFrame([weather_data])
display(df)
df.createOrReplaceTempView("weather")

# %%
# %sql
select time, temperature_2m as temperature
from weather
lateral view posexplode(hourly.temperature_2m) as pos, temperature_2m
lateral view posexplode(hourly.time) as pos2, time
where pos = pos2
